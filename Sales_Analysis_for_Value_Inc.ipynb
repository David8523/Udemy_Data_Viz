# %% [markdown]
# <a href="https://colab.research.google.com/github/David8523/Udemy_projects/blob/main/Sales_Analysis_for_Value_Inc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Sales Analysis for Value Inc**
#
# ## 1. Project introduction and background
#
# Value Inc is a retail store that sells household items all over the world by bulk.
#
# The Sales Manager has no sales reporting but he has a brief idea of current sales. He also has no idea of the monthly cost, profit and top selling products. He wants a dashboard on this and says the data is currently stored in an excel sheet.

# %% [markdown]
# ## 2. Data Exploration and Manipulation
#
# ### 2.1 Importing the libraries and visualizing the first 5 rows

# %%
#importing the required librarie
import pandas as pd

# %%
#loading dataset into dataframe
#from google.colab import files
#uploaded = files.upload()
data = pd.read_csv("transaction.csv")
data.head(5)
# Out:
#                                                                         UserId;TransactionId;Year;Month;Day;Time;ItemCode;ItemDescription;NumberOfItemsPurchased;CostPerItem;SellingPricePerItem;Country;ClientKeywords
# 278166;6355745;2019;Feb;2;12:50:00;465549;FAMIL...  'Solo Entrepreneur'                                 '2-5 Year Client']
# 337701;6283376;2018;Dec;26;09:06:00;482370;LOND...  'Corporation'                                       '2-5 Year Client']
# 267099;6385599;2019;Feb;15;09:45:00;490728;SET ...  'Corporation'                                       '2-5 Year Client']
# 380478;6044973;2018;Jun;22;07:14:00;459186;UNIO...  'Small Business'                                         'New Client']
# -1;6143225;2018;Sep;10;11:58:00;1733592;WASHROO...  'Solo Entrepreneur'                                 '2-5 Year Client']

# %%
#making a table with separation between cells
data = pd.read_csv("transaction.csv",sep=";")
data.head(5)
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
# 3  380478        6044973  2018   Jun   22  07:14:00    459186
# 4      -1        6143225  2018   Sep   10  11:58:00   1733592
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
# 3        UNION JACK FLAG LUGGAGE TAG                       3         1.73
# 4                WASHROOM METAL SIGN                       3         3.40
#
#    SellingPricePerItem         Country  \
# 0                21.11  United Kingdom
# 1                 3.87  United Kingdom
# ...

# %% [markdown]
# ### 2.2 Creating new relevant columns
# Creation of 4 new numerical columns in order to expand the fiancial information per transaction:
# * Cost per transaction: Obtained by multiplying the cost of the product by the number of products sold.
# * Sales per transaction: Sales price of the product multiplied by the quantity sold.
# * Profit per transaction: Subtraction of sales and costs per transaction.
# * Markup: Sales minus costs divided by costs.

# %%
#CostPerTransaction Column Calculation
CostPerItem = data ['CostPerItem']
NumberOfItemsPurchased = data ['NumberOfItemsPurchased']
#Cost per transaction
data['CostPerTransaction'] = CostPerItem * NumberOfItemsPurchased
#Sales per Transaction
data['SalesPerTransaction'] = data['SellingPricePerItem'] * data['NumberOfItemsPurchased']
#Profit calculation = sales - cost
data['ProfitPerTransaction'] = data['SalesPerTransaction'] - data['CostPerTransaction']
#Markup = (sales-cost)/Cost
data['Markup'] = (data['SalesPerTransaction'] - data['CostPerTransaction']) / data['CostPerTransaction']

# %% [markdown]
# ### 2.3 Rounding Markup

# %%
#rounding Markup
data['Markup'] = round(data['Markup'], 3)

# %% [markdown]
# ### 2.2 Combining dates in one column
#
# Combining the columns Day, Month and Year in one column

# %%
#changing data type (month not required)
day = data['Day'].astype(str)
year = data['Year'].astype(str)
data['date'] = day+'-'+data['Month']+'-'+ year
data.head(5)
# so far, so good
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
# 3  380478        6044973  2018   Jun   22  07:14:00    459186
# 4      -1        6143225  2018   Sep   10  11:58:00   1733592
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
# 3        UNION JACK FLAG LUGGAGE TAG                       3         1.73
# 4                WASHROOM METAL SIGN                       3         3.40
#
#    SellingPricePerItem         Country  \
# 0                21.11  United Kingdom
# 1                 3.87  United Kingdom
# ...

# %% [markdown]
# ### 2.2 Splitting Client Keywords in various more detailed columns
# We can divide the keywords in 3 more detailled new columns
# 1. Client Age
# 2. Client type
# 3. Type of contract

# %%
#using spit to plit the client keywoards fiels
split_col = data['ClientKeywords'].str.split(',', expand=True)
#creating new columns for the split columns in client Keywords
data['ClientAge']=split_col[0]
data['ClientType']=split_col[1]
data['ClientContract']=split_col[2]

#using the replace function to clean the new columns
data['ClientAge']=data['ClientAge'].str.replace('[' , '')
data['ClientContract']=data['ClientContract'].str.replace(']' , '')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ### 2.2 Merge files with another CSV file
# Merge with another crucial file that displays the value of the seasons, creating a correlation between season and sales volume

# %%
#from google.colab import files
#uploaded = files.upload()
seasons=pd.read_csv('value_inc_seasons.csv', sep=';')
seasons.head(5)
# Out:
#   Month Season
# 0   Jan   High
# 1   Feb    Mid
# 2   Mar    Low
# 3   Apr    Low
# 4   May    Low

# %%
#mergin the files, creating a new dataset
data=pd.merge(data, seasons, on = 'Month')

# %% [markdown]
# ### 2.2 Deleting irrelevant columns
# columns like day, month, year or the keywords

# %%
#dropping columns
data=data.drop('ClientKeywords', axis=1)
data=data.drop(['Day','Month','Year'], axis=1)

# %% [markdown]
# ### 2.2 Lowercase the products description
#
# Last but no least, lets change the description of the products to lowercase.

# %%
#using the lower function to change item to lowercase
data['ItemDescription']=data['ItemDescription'].str.lower()
data.head(5)
# Out:
#    UserId  TransactionId      Time  ItemCode  \
# 0  278166        6355745  12:50:00    465549
# 1  267099        6385599  09:45:00    490728
# 2  328440        6387425  10:35:00    494802
# 3  364791        6358242  09:25:00    486276
# 4      -1        6388019  13:24:00    490329
#
#                        ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0     family album white picture frame                       6        11.73
# 1    set 12 colour pencils dolly girl                       72         0.90
# 2  set of 6 ribbons perfectly pretty                        36         3.99
# 3        set of 5 mini grocery magnets                       3         2.88
# 4          roll wrap vintage christmas                      30         3.40
#
#    SellingPricePerItem         Country  CostPerTransaction  \
# 0                21.11  United Kingdom               70.38
# 1                 1.62          France               64.80
# ...

# %% [markdown]
# # 3. Visualizing the data on tableau
#
# We finish this project by visualizing the data in on of the most popular BI tool for Data Visualization. [Link visualization Here](https://public.tableau.com/app/profile/david.de.la.iglesia/viz/SalesDashboard_16571521303560/Dashboard1)
